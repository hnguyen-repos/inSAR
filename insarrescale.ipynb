# %%
# !wget http://geodesy.unr.edu/gps_timeseries/tenv3/IGS14/P780.tenv3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('P780.tenv3', sep=' ', skipinitialspace=True, index_col=0)
df
# Out:
#       YYMMMDD  yyyy.yyyy  __MJD  week  d  reflon  _e0(m)  __east(m)  \
# site
# P780  08MAY27  2008.4025  54613  1481  2   -66.6    2208   0.770329
# P780  08MAY28  2008.4052  54614  1481  3   -66.6    2208   0.771100
# P780  08MAY29  2008.4079  54615  1481  4   -66.6    2208   0.773330
# P780  08MAY30  2008.4107  54616  1481  5   -66.6    2208   0.771673
# P780  08MAY31  2008.4134  54617  1481  6   -66.6    2208   0.769366
# ...       ...        ...    ...   ... ..     ...     ...        ...
# P780  23FEB21  2023.1403  59996  2250  2   -66.6    2208   0.866299
# P780  23FEB22  2023.1431  59997  2250  3   -66.6    2208   0.868251
# P780  23FEB23  2023.1458  59998  2250  4   -66.6    2208   0.870266
# P780  23FEB24  2023.1485  59999  2250  5   -66.6    2208   0.870116
# P780  23FEB25  2023.1513  60000  2250  6   -66.6    2208   0.872640
#
#       ____n0(m)  _north(m)  ...  _ant(m)  sig_e(m)  sig_n(m)  sig_u(m)  \
# site                        ...
# P780    1999285   0.828290  ...   0.0083  0.001724  0.001267  0.006427
# P780    1999285   0.828728  ...   0.0083  0.000901  0.000730  0.003357
# P780    1999285   0.829775  ...   0.0083  0.000883  0.000722  0.003321
# P780    1999285   0.826960  ...   0.0083  0.000883  0.000708  0.003274
# P780    1999285   0.827072  ...   0.0083  0.000879  0.000705  0.003236
# ...         ...        ...  ...      ...       ...       ...       ...
# P780    1999285   1.012989  ...   0.0083  0.000807  0.000704  0.003312
# P780    1999285   1.011587  ...   0.0083  0.000822  0.000705  0.003264
# P780    1999285   1.010502  ...   0.0083  0.000831  0.000729  0.003411
# P780    1999285   1.011751  ...   0.0083  0.000803  0.000704  0.003328
# P780    1999285   1.009668  ...   0.0083  0.000861  0.000738  0.003598
#
#       __corr_en  __corr_eu  __corr_nu  _latitude(deg)  _longitude(deg)  \
# site
# P780  -0.104430   0.222023  -0.212698       18.075026       -66.579135
# P780  -0.115969   0.068757  -0.117577       18.075026       -66.579135
# P780  -0.079310   0.135194  -0.105965       18.075026       -66.579135
# P780  -0.069646   0.073039  -0.148988       18.075026       -66.579135
# P780  -0.083593   0.101320  -0.105484       18.075026       -66.579135
# ...         ...        ...        ...             ...              ...
# P780  -0.089855   0.093046  -0.128929       18.075027       -66.579134
# P780  -0.107990   0.107456  -0.091247       18.075027       -66.579134
# P780  -0.080831   0.104894  -0.102193       18.075027       -66.579134
# P780  -0.072242   0.120085  -0.115644       18.075027       -66.579134
# P780  -0.074033   0.052919  -0.112741       18.075027       -66.579134
#
#       __height(m)
# site
# P780    154.06491
# P780    154.07215
# P780    154.07643
# P780    154.08103
# P780    154.08118
# ...           ...
# P780    154.06035
# P780    154.06364
# P780    154.06293
# P780    154.06126
# P780    154.07902
#
# [5326 rows x 22 columns]

# %%
time  = np.array(df["yyyy.yyyy"])
east  = np.array(df["__east(m)"])
north = np.array(df["_north(m)"])
up    = np.array(df["____up(m)"])

# transpose matrix for processing
time  = np.array([time]).T
east  = np.array([east]).T
north = np.array([north]).T
up    = np.array([up]).T
time = np.array([time[time<2020]]).T
n = len(time)
east = np.array([east[0:n, 0]]).T
north = np.array([north[0:n, 0]]).T
up = np.array([up[0:n, 0]]).T

# print(len(time), len(up), len(east), len(north))

fig, axs = plt.subplots(3, 1, sharex=True)
axs[0].plot(time, east , "ko", markersize=1);
axs[0].set_ylabel("East (mm)")
axs[1].plot(time, north, "ko", markersize=1);
axs[1].set_ylabel("North (mm)")
axs[2].plot(time, up   , "ko", markersize=1)
axs[2].set_ylabel("Up (mm)"); axs[2].set_xlabel("Time (Year)")
fig.subplots_adjust(hspace=.0); fig.align_labels(axs[:])

# %% [markdown]
# Earthquake:
# 19sep24 2019.7290
# 20jan06 2020.0137
# 20jan07 2020.0164

# %%
def lsquare(data):
    A = np.concatenate((np.ones((n,1)),time, np.sin(omega*time), np.cos(omega*time),\
                        np.cos(2*omega*time), np.cos(2*omega*time)), axis=1)
    # print(A)
    N = np.dot(A.T, A)
    print(N)
    # print(N.shape)
    coef = np.dot(np.linalg.inv(N), A.T)
    coef = np.dot(coef, data)
    return coef

def lsEst(data):
    coef = lsquare(data)
    # print(coef)
    return coef[0] + coef[1]*t\
        + coef[2]*np.sin(omega*t) + coef[3]*np.cos(omega*t)\
        + coef[4]*np.sin(2*omega*t) + coef[5]*np.cos(2*omega*t)

# intial condition
n = len(time)
omega = 2*np.pi
t = np.linspace(min(time), max(time), 1000)

# estimate displacement
eastEst = lsEst(east)
northEst = lsEst(north)
upEst = lsEst(up)

# plot
fig, axs = plt.subplots(3, 1, sharex=True)
axs[0].plot(time, east , "ko", markersize=1);
axs[0].set_ylabel("East (mm)")
axs[0].plot(t, eastEst)
axs[1].plot(time, north, "ko", markersize=1);
axs[1].set_ylabel("North (mm)")
axs[1].plot(t, northEst)
axs[2].plot(time, up   , "ko", markersize=1)
axs[2].plot(t, upEst)
axs[2].set_ylabel("Up (mm)"); axs[2].set_xlabel("Time (Year)")
fig.subplots_adjust(hspace=.0); fig.align_labels(axs[:])
# Out:
# [[ 4.21400000e+03  8.48780936e+06 -1.09536587e+02 -3.14700156e+01
#    3.88381850e+01  3.88381850e+01]
#  [ 8.48780936e+06  1.70961337e+10 -2.20675359e+05 -6.31549194e+04
#    7.80722269e+04  7.80722269e+04]
#  [-1.09536587e+02 -2.20675359e+05  2.08758091e+03 -1.58880238e+01
#    5.51178647e+01  5.51178647e+01]
#  [-3.14700156e+01 -6.31549194e+04 -1.58880238e+01  2.12641909e+03
#   -2.58984124e+01 -2.58984124e+01]
#  [ 3.88381850e+01  7.80722269e+04  5.51178647e+01 -2.58984124e+01
#    2.11241999e+03  2.11241999e+03]
#  [ 3.88381850e+01  7.80722269e+04  5.51178647e+01 -2.58984124e+01
#    2.11241999e+03  2.11241999e+03]]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[3], line 25
#      22 t = np.linspace(min(time), max(time), 1000)
#      24 # estimate displacement
# ---> 25 eastEst = lsEst(east)
#      26 northEst = lsEst(north)
#      27 upEst = lsEst(up)
#
# Cell In[3], line 13, in lsEst(data)
#      12 def lsEst(data):
# ---> 13     coef = lsquare(data)
#      14     # print(coef)
#      15     return coef[0] + coef[1]*t\
#      16         + coef[2]*np.sin(omega*t) + coef[3]*np.cos(omega*t)\
#      17         + coef[4]*np.sin(2*omega*t) + coef[5]*np.cos(2*omega*t)
#
# Cell In[3], line 8, in lsquare(data)
#       6 print(N)
#       7 # print(N.shape)
# ----> 8 coef = np.dot(np.linalg.inv(N), A.T)
#       9 coef = np.dot(coef, data)
#      10 return coef
#
# File <__array_function__ internals>:200, in inv(*args, **kwargs)
#
# File ~/miniconda3/envs/geo/lib/python3.11/site-packages/numpy/linalg/linalg.py:538, in inv(a)
#     536 signature = 'D->D' if isComplexType(t) else 'd->d'
#     537 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 538 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     539 return wrap(ainv.astype(result_t, copy=False))
#
# File ~/miniconda3/envs/geo/lib/python3.11/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
